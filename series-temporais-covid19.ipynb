# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('COVID-19-cases-brazil-states.csv')

# %%
df.shape
# Out:
# (18214, 26)

# %%
df.head()
# Out:
#    epi_week        date country  state   city  newDeaths  deaths  newCases  \
# 0         9  2020-02-25  Brazil     SP  TOTAL          0       0         1
# 1         9  2020-02-25  Brazil  TOTAL  TOTAL          0       0         1
# 2         9  2020-02-26  Brazil     SP  TOTAL          0       0         0
# 3         9  2020-02-26  Brazil  TOTAL  TOTAL          0       0         0
# 4         9  2020-02-27  Brazil     SP  TOTAL          0       0         0
#
#    totalCases  deathsMS  ...  tests  tests_per_100k_inhabitants  vaccinated  \
# 0           1         0  ...    NaN                         NaN         NaN
# 1           1         0  ...    NaN                         NaN         NaN
# 2           1         0  ...    NaN                         NaN         NaN
# 3           1         0  ...    NaN                         NaN         NaN
# 4           1         0  ...    NaN                         NaN         NaN
#
#    vaccinated_per_100_inhabitants  vaccinated_second  \
# ...

# %%
df.tail()
# Out:
#        epi_week        date country  state   city  newDeaths  deaths  \
# 18209       151  2021-12-22  Brazil     SC  TOTAL          0   20135
# 18210       151  2021-12-22  Brazil     SE  TOTAL          0    6056
# 18211       151  2021-12-22  Brazil     SP  TOTAL          0  155008
# 18212       151  2021-12-22  Brazil     TO  TOTAL          0    3927
# 18213       151  2021-12-22  Brazil  TOTAL  TOTAL          0  618213
#
#        newCases  totalCases  deathsMS  ...       tests  \
# 18209         0     1238751     20135  ...   2568392.0
# 18210         0      278439      6056  ...    604183.0
# 18211         0     4450144    155008  ...  19501783.0
# 18212         0      234113      3927  ...    721136.0
# 18213         0    22223849    617948  ...  65497639.0
#
#        tests_per_100k_inhabitants   vaccinated  \
# 18209                 35847.42493    5776792.0
# 18210                 26283.72782    1736819.0
# 18211                 42469.91918   38244847.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18214 entries, 0 to 18213
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   epi_week                               18214 non-null  int64
#  1   date                                   18214 non-null  object
#  2   country                                18214 non-null  object
#  3   state                                  18214 non-null  object
#  4   city                                   18214 non-null  object
#  5   newDeaths                              18214 non-null  int64
#  6   deaths                                 18214 non-null  int64
#  7   newCases                               18214 non-null  int64
#  8   totalCases                             18214 non-null  int64
#  9   deathsMS                               18214 non-null  int64
# ...

# %%
df.describe()
# Out:
#            epi_week     newDeaths         deaths       newCases    totalCases  \
# count  18214.000000  18214.000000   18214.000000   18214.000000  1.821400e+04
# mean      83.179862     67.883277   20985.524871    2440.304052  7.577081e+05
# std       48.497703    237.478655   69351.207298    8023.097762  2.485051e+06
# min        9.000000    -38.000000       0.000000   -1582.000000  1.000000e+00
# 25%       34.000000      4.000000    1607.250000     180.000000  7.484775e+04
# 50%      105.000000     13.000000    5371.000000     608.000000  2.208180e+05
# 75%      128.000000     37.000000   12852.750000    1534.000000  4.969495e+05
# max      151.000000   4148.000000  618213.000000  124878.000000  2.222385e+07
#
#             deathsMS  totalCasesMS  deaths_per_100k_inhabitants  \
# count   18214.000000  1.821400e+04                 18214.000000
# mean    20968.180081  7.572061e+05                   139.679631
# std     69307.904988  2.483917e+06                   108.867446
# ...

# %%
df.describe(include='object')
# Out:
#               date country  state   city
# count        18214   18214  18214  18214
# unique         667       1     28      1
# top     2021-10-14  Brazil  TOTAL  TOTAL
# freq            28   18214    667  18214

# %%
from pandas_profiling import ProfileReport

# %%
relatorio_completo = ProfileReport(df, title='Relatorio Completo Covid19')
relatorio_completo.to_file('relatorio_completo_covid19.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
